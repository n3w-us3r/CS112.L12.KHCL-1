# %% [markdown]
# #KHÓA SỐ
#
# Để tăng độ an toàn chống hiện tượng cướp ngân hàng ngày càng phổ biến người ta dùng khóa số với mã mở khóa đơn giản nhưng rất hiệu quả. Trên cửa ra vào hiển thị một xâu khá dài các ký tự số. Các chữ số có thể di chuyển đổi chổ cho nhau hoặc bị xóa. Muốn mở khóa người ta phải di chuyển các chữ số và trong trường hợp cần thiết – xóa vài chữ số để nhận được xâu lớn nhất thỏa mãn điều kiện đã cài đặt. Điều kiện này được thay đổi thường xuyên. Hôm nay điều kiện đó là “Số nhận được phải chia hết cho 3”. Số nhận được có thể bắt đầu bằng các chữ số 0. Xâu “000” sẽ lớn hơn xâu “00”.
#
# Hãy xác định khóa mở cửa.
#
# Dữ liệu: Vào từ thiết bị nhập chuẩn gồm một xâu ký tự số có độ dài lớn hơn 2 và không vượt quá 105.
#
# Kết quả: Đưa ra thiết bị xuất chuẩn xâu khóa mở cửa.
#
# Ví dụ:
#
# | Input |  Output |
# | --- | --- |
# | 105 | 510 |

# %% [markdown]
# #1.Abstraction
# Cho 1 chuỗi số có độ dài n , thực hiện việc đổi chỗ hoặc xoá các chữ số để được một số lớn nhất chia hết cho 3
# >## Input Format
# 1 chuỗi số có n ký tự ( 2 $<$ n $\leq$$10^5$)
# >## Output Format
# 1 chuỗi số là kết quả của bài toán
# >## Constraint
# Chuỗi số chỉ gồm các số từ 0-9

# %% [markdown]
# # 2. Decomposition
#
# Bài toán có thể được chia làm 2 bài toán con: <br>
#   - Tìm số lớn nhất có thể cấu thành từ các chữ số sẵn có
#   - Xóa bớt 1 vài chữ số để thu được 1 số chia hết cho 3 nếu cần thiết
#
# # 3. Pattern recognition
#
#   - Tìm số lớn nhất có thể cấu thành từ các chữ số sẵn có: sắp xếp
#   - Xóa bớt 1 hay nhiều chữ số để thu được 1 số chia hết cho 3: toán
#
# #4. Algorithm design
# ##Time Complexity
# Trong bài toán sử dụng counting sort O(n)
#
# ⇒  Độ phức tạp thuật toán O(n)
#
# Cần lưu trữ xâu chuỗi cố độ dài n
#
# ⇒  Độ phức tạp không gian  : O(n)
# ## Phân tích bài toán
# Như đã đề cập ở Decomposition . Bài toán được chia thành 2 bài toán con nhỏ
#
#
# ### Kiến thức bổ trợ:
# -Một số chia hết cho 3 khi tổng của các chữ số của số đó chia hết cho 3
#
# ###Giải thuật :
#
# B1.Tính tổng của các chữ số trong chuỗi số
#
# B2.Nếu tổng chia hết cho 3 thì sắp xếp chuỗi giảm dần => Kết quả bài toán
#
# B3.Nếu tổng không chia hết cho 3:
#
# >Sort các chữ số tăng dần . Mục đích của việc sort là để khi xoá các chữ số chúng ta sẽ ưu tiên xoá các chữ số nhỏ nhất để phục vụ cho mục đích chung của chúng ta là tìm số lớn nhất chia hết cho 3
#
# Xét 2 trường hợp
#
#   **TH1.** sum % 3 = 1  . Trường hợp này có 2 cách giải quyết:
#
# **1. Xoá 1 chữ số có số dư là 1 khi chia cho 3**
#
# >VD. 12537 có sum = 15 và sum %3 =1
#
# $\Rightarrow$ Xoá số  1 , số mới là 345 sẽ chia hết cho 3
#
# **2. Xoá 2 chữ số có số dư là 2 khi chia cho 3**
# nếu cách 1 không giải quyết được
#
# >VD. 235 có sum = 15 và sum %3 =1  . Ở đây không có số nào có số dư 1 khi chia cho 3
#
# $\Rightarrow$ Xoá 2 và  5 vì
#
# **TH2** sum % 3 = 2 . Trường hợp này cũng tương tự có 2 cách giải quyết.
#
# **1. Xoá 1 chữ số có số dư là 2 khi chia cho 3**
#
# >VD. 1235 có sum = 11 và sum %3 =2
#
# $\Rightarrow$ Xoá số  2 , số mới là 135 sẽ chia hết cho 3
#
# **2.Xoá 2 chữ số có số dư là 1 khi chia cho 3** nếu cách 1 không giải quyết được
#
# >VD. 0134 sum = 8 và sum %3 =2  .
#
# $\Rightarrow$ Xoá 1 và  4
#
#
#
#
# B4. Đảo chuỗi lại để được số lớn nhất
#
#
#
#
# # 5. Psuedocode
#
# ```
# // initialize an array with size of 10 elements of 0
# // this is the counting sort array
# count = array[int](10, 0)
#
# func sort_in_ascending(arr: array[int], arr_len: int) -> void:
# begin
#
#     for i from 0 to size(arr)-1:
#     begin
#         count[arr[i]] += 1
#     end
#
#     index: int initialized with 0
#     for i from 0 to 9:
#     begin
#         while count[i] > 0:
#         begin
#           arr[index] = i
#           index += 1
#           count[i] -= 1
#         end
#     end
# end
#
# func sort_in_descending(arr: array[int], arr_len: int) -> void:
# begin
#
#     for i from 0 to size(arr)-1:
#     begin
#         count[arr[i]] += 1
#     end
#
#     index: int initialized with 0
#     for i from 9 to 0:
#     begin
#         while count[i] > 0:
#         begin
#           arr[index] = i
#           index += 1
#           count[i] -= 1
#         end
#     end
# end
#
# func removeAndPrintResult(arr: array[int], arr_len: int, ind1: int, ind2: int intialized with -1) -> void:
# begin
#     s: string initialize with ""
#     for i from arr_len - 1 to 0:
#     begin
#         if i != ind1 and i != ind2:
#         begin
#             s += parse_to_string(arr[i])
#         end
#     end
#
#     print(s)
# end
#
# func largest3Multiple(arr: array[int], arr_len: int) -> void:
# begin
#     sum_digits = sum(arr)
#
#
#     if sum_digits % 3 == 0:
#     begin
#         sort_in_descending(arr, arr_len)
#         print(parse_to_string(arr))
#         return
#     end
#
#     sort_in_ascending(arr, arr_len)
#     if sum_digits % 3 == 1:
#     begin
#       ind1 = -1
#       ind2 = -1
#
#       for i from 0 to arr_len - 1:
#       begin
#         if arr[i] % 3 == 1:
#         begin
#           removeAndPrintResult(arr, arr_len, ind1)
#           return
#         end
#
#         if arr[i] % 3 == 2:
#         begin
#           if ind1 == -1:
#           begin
#             ind1 = i
#           end
#           elif ind2 == -1:
#           begin
#             ind2 = i
#           end
#         end
#
#         if ind1 != -1 and ind2 != -1:
#         begin
#           removeAndPrintResult(arr, arr_len, ind1, ind2)
#           return
#         end
#       end
#     end
#
#     if sum_digits % 3 == 2:
#     begin
#       ind1 = -1
#       ind2 = -1
#
#       for i from 0 to arr_len - 1:
#       begin
#         if arr[i] % 3 == 2:
#         begin
#           removeAndPrintResult(arr, arr_len, ind1)
#           return
#         end
#
#         if arr[i] % 3 == 1:
#         begin
#           if ind1 == -1:
#           begin
#             ind1 = i
#           end
#           elif ind2 == -1:
#           begin
#             ind2 = i
#           end
#         end
#
#         if ind1 != -1 and ind2 != -1:
#         begin
#           removeAndPrintResult(arr, arr_len, ind1, ind2)
#           return
#         end
#       end
#     end
#
#     print('0')
#
# end
# ```

# %% [markdown]
# #5. Implementation

# %%
MAX_SIZE = 10




def sort_in_ascending(arr, n):


    count = [0]*MAX_SIZE
    for i in range(n):
        count[arr[i]] += 1


    index = 0
    for i in range(MAX_SIZE):
        while count[i] > 0:
            arr[index] = i
            index += 1
            count[i] -= 1
def sort_in_descending(arr, n):

    count = [0]*MAX_SIZE
    for i in range(n):
        count[arr[i]] += 1


    index = 0
    for i in range(MAX_SIZE-1,-1,-1):
        while count[i] > 0:
            arr[index] = i
            index += 1
            count[i] -= 1


def removeAndPrintResult(arr, n, ind1, ind2=-1):
    s=''
    for i in range(n-1, -1, -1):
        if i != ind1 and i != ind2:
            s+=str(arr[i])
    print(s)


def largest3Multiple(arr, n):

 
    s = sum(arr)

    if s % 3 == 0:
        string=''
        sort_in_descending(arr,n)
        arr=[str(x) for x in arr]
        string=''.join(arr)
        print(string)
        return 

  
    sort_in_ascending(arr, n)


    remainder = s % 3


    if remainder == 1:
        rem_2 = [0]*2
        rem_2[0] = -1
        rem_2[1] = -1

        for i in range(n):

            
            if arr[i] % 3 == 1:
                removeAndPrintResult(arr, n, i)
                return True

            if arr[i] % 3 == 2:

               
                if rem_2[0] == -1:
                    rem_2[0] = i

              
                elif rem_2[1] == -1:
                    rem_2[1] = i

        if rem_2[0] != -1 and rem_2[1] != -1:
            removeAndPrintResult(arr, n, rem_2[0], rem_2[1])
            return True


    elif remainder == 2:
        rem_1 = [0]*2
        rem_1[0] = -1
        rem_1[1] = -1

     
        for i in range(n):

    
            if arr[i] % 3 == 2:
                removeAndPrintResult(arr, n, i)
                return True

            if arr[i] % 3 == 1:

             
                if rem_1[0] == -1:
                    rem_1[0] = i

              
                elif rem_1[1] == -1:
                    rem_1[1] = i

        if rem_1[0] != -1 and rem_1[1] != -1:
            removeAndPrintResult(arr, n, rem_1[0], rem_1[1])
            return True

    print("Not possible")
    return False



if __name__ == "__main__":

    arr = [int(x) for x in input().strip()]
    n = len(arr)
    largest3Multiple(arr, n)
